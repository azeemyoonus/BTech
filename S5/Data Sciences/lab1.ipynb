# %%
import pandas

# %%
url="B:\sem 5\data science\meteorite-landings.csv"
data = pandas.read_csv(url)
print(data.shape)
# Out:
# (45716, 10)

# %% [markdown]
# Q2

# %%
#2
mydataframe = pandas.DataFrame(data)
print(mydataframe)
# Out:
#              name     id nametype              recclass      mass   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#          year    reclat    reclong               GeoLocation
# ...

# %%
mydataframe.describe()
# Out:
#                  id          mass          year        reclat       reclong
# count  45716.000000  4.558500e+04  45428.000000  38401.000000  38401.000000
# mean   26889.735104  1.327808e+04   1991.772189    -39.122580     61.074319
# std    16860.683030  5.749889e+05     27.181247     46.378511     80.647298
# min        1.000000  0.000000e+00    301.000000    -87.366670   -165.433330
# 25%    12688.750000  7.200000e+00   1987.000000    -76.714240      0.000000
# 50%    24261.500000  3.260000e+01   1998.000000    -71.500000     35.666670
# 75%    40656.750000  2.026000e+02   2003.000000      0.000000    157.166670
# max    57458.000000  6.000000e+07   2501.000000     81.166670    354.473330

# %% [markdown]
# Q3

# %%
mydataframe['year'].describe()
# Out:
# count    45428.000000
# mean      1991.772189
# std         27.181247
# min        301.000000
# 25%       1987.000000
# 50%       1998.000000
# 75%       2003.000000
# max       2501.000000
# Name: year, dtype: float64

# %% [markdown]
# Q4

# %%
newdataframea = mydataframe.loc[((mydataframe['year']<860) | (mydataframe['year']>2016)) ]
newdataframeb = mydataframe.loc[((mydataframe['reclong']>= -180) & (mydataframe['reclong']<=180))]
newdataframec = mydataframe.loc[((mydataframe['reclat']==0)& (mydataframe['reclong']==0))]
# Out:
#                         name     id nametype   recclass    mass   fall  \
# 37     Northwest Africa 5815  50693    Valid         L5  256.80  Found
# 596              Mason Gully  53653    Valid         H5   24.54   Fell
# 1648       Allan Hills 09004  52119    Valid  Howardite  221.70  Found
# 1649       Allan Hills 09005  55797    Valid         L5  122.30  Found
# 1650       Allan Hills 09006  55798    Valid         H5  104.30  Found
# ...                      ...    ...      ...        ...     ...    ...
# 45655          Yamato 984144  40764    Valid         H6   37.44  Found
# 45656          Yamato 984145  40765    Valid         L6   54.80  Found
# 45657          Yamato 984146  40766    Valid         H3   19.32  Found
# 45658          Yamato 984147  40767    Valid        LL6  118.90  Found
# 45659          Yamato 984148  40768    Valid         L5    4.59  Found
#
#          year  reclat  reclong           GeoLocation
# 37        NaN     0.0      0.0  (0.000000, 0.000000)
# ...

# %%
newdataframea
# Out:
#                         name     id nametype           recclass   mass   fall  \
# 16356                 Havana  11857    Valid  Iron, IAB complex    NaN  Found
# 30679  Northwest Africa 7701  57150    Valid                CK6   55.0  Found
# 38188                     Ur  24125    Valid               Iron    NaN  Found
# 38301        Wietrzno-Bobrka  24259    Valid               Iron  376.0  Found
#
#          year    reclat   reclong              GeoLocation
# 16356   301.0  40.33333 -90.05000  (40.333330, -90.050000)
# 30679  2101.0   0.00000   0.00000     (0.000000, 0.000000)
# 38188  2501.0  30.90000  46.01667   (30.900000, 46.016670)
# 38301   601.0  49.41667  21.70000   (49.416670, 21.700000)

# %%
newdataframeb
# Out:
#              name     id nametype              recclass      mass   fall  \
# 0          Aachen      1    Valid                    L5      21.0   Fell
# 1          Aarhus      2    Valid                    H6     720.0   Fell
# 2            Abee      6    Valid                   EH4  107000.0   Fell
# 3        Acapulco     10    Valid           Acapulcoite    1914.0   Fell
# 4         Achiras    370    Valid                    L6     780.0   Fell
# ...           ...    ...      ...                   ...       ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite     172.0  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped      46.0  Found
# 45713        Zlin  30410    Valid                    H4       3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6    2167.0  Found
# 45715  Zulu Queen  30414    Valid                  L3.7     200.0  Found
#
#          year    reclat    reclong               GeoLocation
# ...

# %%
newdataframec
# Out:
#                         name     id nametype   recclass    mass   fall  \
# 37     Northwest Africa 5815  50693    Valid         L5  256.80  Found
# 596              Mason Gully  53653    Valid         H5   24.54   Fell
# 1648       Allan Hills 09004  52119    Valid  Howardite  221.70  Found
# 1649       Allan Hills 09005  55797    Valid         L5  122.30  Found
# 1650       Allan Hills 09006  55798    Valid         H5  104.30  Found
# ...                      ...    ...      ...        ...     ...    ...
# 45655          Yamato 984144  40764    Valid         H6   37.44  Found
# 45656          Yamato 984145  40765    Valid         L6   54.80  Found
# 45657          Yamato 984146  40766    Valid         H3   19.32  Found
# 45658          Yamato 984147  40767    Valid        LL6  118.90  Found
# 45659          Yamato 984148  40768    Valid         L5    4.59  Found
#
#          year  reclat  reclong           GeoLocation
# 37        NaN     0.0      0.0  (0.000000, 0.000000)
# ...

# %% [markdown]
# Q5

# %%
print(newdataframea.isnull())
print(newdataframeb.isnull())
print(newdataframec.isnull())

# newdataframea.any()
# Out:
#         name     id  nametype  recclass   mass   fall   year  reclat  reclong  \
# 16356  False  False     False     False   True  False  False   False    False
# 30679  False  False     False     False  False  False  False   False    False
# 38188  False  False     False     False   True  False  False   False    False
# 38301  False  False     False     False  False  False  False   False    False
#
#        GeoLocation
# 16356        False
# 30679        False
# 38188        False
# 38301        False
#         name     id  nametype  recclass   mass   fall   year  reclat  reclong  \
# 0      False  False     False     False  False  False  False   False    False
# 1      False  False     False     False  False  False  False   False    False
# 2      False  False     False     False  False  False  False   False    False
# 3      False  False     False     False  False  False  False   False    False
# 4      False  False     False     False  False  False  False   False    False
# ...

# %% [markdown]
# Q6

# %%
bool_series = pandas.isnull(mydataframe["mass"])
mydataframe[bool_series]
# Out:
#                     name     id nametype      recclass  mass   fall    year  \
# 12       Aire-sur-la-Lys    425    Valid       Unknown   NaN   Fell  1769.0
# 38                Angers   2301    Valid            L6   NaN   Fell  1822.0
# 76     Barcelona (stone)   4944    Valid            OC   NaN   Fell  1704.0
# 93              Belville   5009    Valid            OC   NaN   Fell  1937.0
# 172    Castel Berardenga   5292    Valid    Stone-uncl   NaN   Fell  1791.0
# ...                  ...    ...      ...           ...   ...    ...     ...
# 38275     Wei-hui-fu (a)  24231    Valid          Iron   NaN  Found  1931.0
# 38276     Wei-hui-fu (b)  24232    Valid          Iron   NaN  Found  1931.0
# 38278            Weiyuan  24233    Valid  Mesosiderite   NaN  Found  1978.0
# 41460      Yamato 792768  28117    Valid           CM2   NaN  Found  1979.0
# 45698      Zapata County  30393    Valid          Iron   NaN  Found  1930.0
#
#          reclat    reclong               GeoLocation
# ...

# %% [markdown]
# Q7

# %%
correct_lat_long_df = mydataframe['mass'].describe()
correct_lat_long_df = pandas.DataFrame(correct_lat_long_df)
# type(correct_lat_long_df)
correct_lat_long_df
# Out:
#                mass
# count  4.558500e+04
# mean   1.327808e+04
# std    5.749889e+05
# min    0.000000e+00
# 25%    7.200000e+00
# 50%    3.260000e+01
# 75%    2.026000e+02
# max    6.000000e+07

# %% [markdown]
# Q8

# %%
inds = pandas.isnull(mydataframe['mass']).any(0).nonzero()[0]
print(inds)
# Out:
# [0]
# C:\Users\Boudhik Shaj\AppData\Local\Temp\ipykernel_10900\875962953.py:1: DeprecationWarning: Calling nonzero on 0d arrays is deprecated, as it behaves surprisingly. Use `atleast_1d(cond).nonzero()` if the old behavior was intended. If the context of this warning is of the form `arr[nonzero(cond)]`, just use `arr[cond]`.
#   inds = pandas.isnull(mydataframe['mass']).any(0).nonzero()[0]
